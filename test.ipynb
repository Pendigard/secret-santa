# %%
import sqlite3


conn = sqlite3.connect('secret_santa.db')

cursor = conn.cursor()



cursor.execute("""
INSERT INTO players (username, link_id) VALUES ('Alice', 'abc123')
""")

# %%
cursor.execute('''
SELECT * FROM players
''')
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (None, 'Alice', None, 'abc123')
